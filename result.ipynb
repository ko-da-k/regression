# %%
# %matplotlib inline

# %%
# %run sample.py

# %%
model.coef
# Out:
#    Coefficients         Name
# 0     -0.210271  SepalLength
# 1      0.228777   SepalWidth
# 2      0.526088  PetalLength

# %%
pd.ols(y=data["SepalLength"],x=data.iloc[:,1:4])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <SepalWidth> + <PetalLength> + <PetalWidth> + <intercept>
#
# Number of Observations:         150
# Number of Degrees of Freedom:   4
#
# R-squared:         0.8592
# Adj R-squared:     0.8563
#
# Rmse:              0.3139
#
# F-stat (3, 146):   297.0182, p-value:     0.0000
#
# Degrees of Freedom: model 3, resid 146
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#     SepalWidth     0.6549     0.0667       9.82     0.0000     0.5242     0.7855
#    PetalLength     0.7111     0.0566      12.56     0.0000     0.6001     0.8220
#     PetalWidth    -0.5626     0.1271      -4.43     0.0000    -0.8117    -0.3134
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
eq = model.criterion_column + "~" + "+".join(model.explanatory_columns)
models = smf.ols(formula=eq,data=data).fit()

# %%
models.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             PetalWidth   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     736.9
# Date:                Sun, 11 Sep 2016   Prob (F-statistic):           6.20e-88
# Time:                        19:37:18   Log-Likelihood:                 36.809
# No. Observations:                 150   AIC:                            -65.62
# Df Residuals:                     146   BIC:                            -53.57
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept      -0.2487      0.178     -1.396      0.165        -0.601     0.103
# ...

# %%
models.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.937
# Dependent Variable: PetalWidth       AIC:                -65.6174
# Date:               2016-09-11 19:37 BIC:                -53.5749
# No. Observations:   150              Log-Likelihood:     36.809
# Df Model:           3                F-statistic:        736.9
# Df Residuals:       146              Prob (F-statistic): 6.20e-88
# R-squared:          0.938            Scale:              0.036823
# ------------------------------------------------------------------
#                Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ------------------------------------------------------------------
# Intercept     -0.2487    0.1781  -1.3963  0.1647  -0.6008   0.1033
# SepalLength   -0.2103    0.0475  -4.4258  0.0000  -0.3042  -0.1164
# SepalWidth     0.2288    0.0490   4.6692  0.0000   0.1319   0.3256
# ...
